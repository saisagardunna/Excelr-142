# %%
from transformers import pipline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-084329af059d> in <cell line: 0>()
# ----> 1 from transformers import pipline
#
# ImportError: cannot import name 'pipline' from 'transformers' (/usr/local/lib/python3.11/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from transformers import pipline
from huggingface_hub import login
login(token="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")
translator=pipline("translation",model="Helsinki-NLP/opus-mt-en-hi")
english_text="hello, How are you?"
result=translator(english_text)
print("Translate Text:",result[0]['translation_text'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e4d1256a80fa> in <cell line: 0>()
# ----> 1 from transformers import pipline
#       2 from huggingface_hub import login
#       3 login(token="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")
#       4 translator=pipline("translation",model="Helsinki-NLP/opus-mt-en-hi")
#       5 english_text="hello, How are you?"
#
# ImportError: cannot import name 'pipline' from 'transformers' (/usr/local/lib/python3.11/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
from transformers import pipeline
from huggingface_hub import login

# Login to Hugging Face (avoid hardcoding tokens, use environment variables)
login(token="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")

# Use the correct task name
translator = pipeline("translation_en_to_hi", model="Helsinki-NLP/opus-mt-en-hi")

# Input text
english_text = "Hello, how are you?"

# Translate
result = translator(english_text)

# Print translation result
print("Translated Text:", result[0]['translation_text'])
# Out:
# Device set to use cpu
# Translated Text: हैलो, तुम कैसे हो?
