# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/232.6 kB 660.6 kB/s eta 0:00:01
#    -------------------------- ------------- 153.6/232.6 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 232.6/232.6 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2,urllib,nltk
from io import BytesIO
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import urllib.request
import PyPDF2
from io import BytesIO
response = urllib.request.urlopen("https://www.udri.org/pdf/02%20working%20paper%201.pdf")
pdf_bytes = response.read()
pdf_reader = PyPDF2.PdfReader(BytesIO(pdf_bytes))
text = pdf_reader.pages[0].extract_text()
print(text)
# Out:
#
#
#  Development  Plan for Greater Mumbai 2014‐2034

# %%
pageObj = pdf_reader.pages[2]
page2 = pageObj.extract_text()
punctuations = ['(',') ',';',':','[',']',',','...','.']
tokens = word_tokenize(page2)
stop_words = stopwords.words('english')
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

print(keywords)
# Out:
# ['Development', 'Plan', 'Greater', 'Mumbai', '2014‐2034', 'Table', 'Contents', 'The', 'Consultant', 'wishes', 'thank', 'following', 'individuals', 'Municipal', 'Corporation', 'Greater', 'Mumbai', 'invaluable', 'support', 'insights', 'contributions', 'towards', '‘', 'Working', 'Paper', '1', '–', 'Preparation', 'Base', 'Map', '’', 'preparation', 'Development', 'Plan', 'Greater', 'Mumbai', '2014‐34', '.............................................................................................................................', '..............', '3', 'Our', 'gratitude', 'following', 'experts', 'invaluable', 'insights', 'support', '............................', '3', 'We', 'wish', 'especially', 'thank', 'MCGM', 'officers', 'Mr.', 'Jagdish', 'Talreja', 'Mr.', 'Dinesh', 'Naik', 'Mr.', 'Hiren', 'Daftardar', 'Ms.', 'Anita', 'Naik', 'continual', 'support', 'since', 'beginning', 'project', 'help', 'towards', 'familiarization', 'data', 'collection', 'They', 'instrumental', 'helping', 'contact', 'various', 'MCGM', 'departments', 'well', 'helping', 'establish', 'contact', 'personnel', 'government', 'departments', 'organizations', 'Many', 'thanks', 'MCGM', 'team', 'deploying', 'personnel', 'particularly', 'Mr.', 'Prasad', 'Gharat', 'extensive', 'field', 'visits', 'helped', 'understanding', 'actual', 'ground', 'conditions', '........................................................................................', '3', 'BEST', '...............................................................................................................................', '.................', '5', 'Brihanmumbai', 'Electric', 'Supply', 'Transport', 'Undertaking', '..............................................................', '5', 'CIDCO', '...............................................................................................................................', '..............', '5', 'City', 'Industrial', 'Development', 'Corporation', '...............................................................................', '5', 'CTP', '...............................................................................................................................', '..................', '5', 'Comprehensive', 'Transportation', 'Plan', '...............................................................................................', '5', 'DP', '...............................................................................................................................', '....................', '5', 'Development', 'Plan', '..........................................................................................................................', '5', 'DPGM34', '...............................................................................................................................', '..........', '5', 'Development', 'Plan', 'Greater', 'Mumbai', '2034', '.......................................................................................', '5', 'DCR', '...............................................................................................................................', '..................', '5', 'Development', 'Control', 'Regulations', '...................................................................................................', '5', 'DGPS', '...........................................................................................................................', '....................', '5', 'Digital', 'Global', 'Positioning', 'System', '...................................................................................................', '5', 'DPGM', '...............................................................................................................................', '..............', '5', 'Development', 'Plan', 'Greater', 'Mumbai', '...........................................................................................', '5', 'ELU', '.................................................................................. ...

# %%
keywords
# Out:
# ['Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐2034',
#  'Table',
#  'Contents',
#  'The',
#  'Consultant',
#  'wishes',
#  'thank',
#  'following',
#  'individuals',
#  'Municipal',
#  'Corporation',
#  'Greater',
#  'Mumbai',
#  'invaluable',
#  'support',
#  'insights',
#  'contributions',
#  'towards',
#  '‘',
#  'Working',
#  'Paper',
#  '1',
#  '–',
#  'Preparation',
#  'Base',
#  'Map',
#  '’',
#  'preparation',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐34',
#  '.............................................................................................................................',
#  '..............',
#  '3',
#  'Our',
#  'gratitude',
#  'following',
#  'experts',
#  'invaluable',
#  'insights',
#  'support',
#  '............................',
#  '3',
#  'We',
#  'wish',
#  'especially',
#  'thank',
#  'MCGM',
#  'officers',
#  'Mr.',
#  'Jagdish',
#  'Talreja',
#  'Mr.',
#  'Dinesh',
#  'Naik',
#  'Mr.',
#  'Hiren',
#  'Daftardar',
#  'Ms.',
#  'Anita',
#  'Naik',
#  'continual',
#  'support',
#  'since',
#  'beginning',
#  'project',
#  'help',
#  'towards',
#  'familiarization',
#  'data',
#  'collection',
#  'They',
#  'instrumental',
#  'helping',
#  'contact',
#  'various',
#  'MCGM',
#  'departments',
#  'well',
#  'helping',
#  'establish',
#  'contact',
#  'personnel',
#  'government',
#  'departments',
#  'organizations',
#  'Many',
#  'thanks',
#  'MCGM',
#  'team',
#  'deploying',
#  'personnel',
#  'particularly',
#  'Mr.',
#  'Prasad',
#  'Gharat',
#  'extensive',
#  'field',
#  'visits',
#  'helped',
#  'understanding',
#  'actual',
#  'ground',
#  'conditions',
#  '........................................................................................',
#  '3',
#  'BEST',
#  '...............................................................................................................................',
#  '.................',
#  '5',
#  'Brihanmumbai',
#  'Electric',
#  'Supply',
#  'Transport',
#  'Undertaking',
#  '..............................................................',
#  '5',
#  'CIDCO',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'City',
#  'Industrial',
#  'Development',
#  'Corporation',
#  '...............................................................................',
#  '5',
#  'CTP',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Comprehensive',
#  'Transportation',
#  'Plan',
#  '...............................................................................................',
#  '5',
#  'DP',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Development',
#  'Plan',
#  '..........................................................................................................................',
#  '5',
#  'DPGM34',
#  '...............................................................................................................................',
#  '..........',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2034',
#  '.......................................................................................',
#  '5',
#  'DCR',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Development',
#  'Control',
#  'Regulations',
#  '...................................................................................................',
#  '5',
#  'DGPS',
#  '...........................................................................................................................',
#  '....................',
#  '5',
#  'Digital',
#  'Global',
#  'Positioning',
#  'System',
#  '...................................................................................................',
#  '5',
#  'DPGM',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '...........................................................................................',
#  '5',
#  'ELU',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Existing',
#  'Land',
#  'use',
#  '.............................................................................................................................',
#  '5',
#  'FSI',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Floor',
#  'Space',
#  'Index',
#  '............................................................................................................................',
#  '5',
#  'GIS',
#  '...............................................................................................................................',
#  '...................',
#  '5']

# %%
name_list = list()
check = ['Mr.', 'Mrs.', 'Ms.']
for idx, token in enumerate(tokens):
    if token.startswith(tuple(check)) and idx < (len(tokens)-1):
        name = token + tokens[idx+1] + ' ' + tokens[idx+2]
        name_list.append(name)
print(name_list)
# Out:
# ['Mr.Jagdish Talreja', 'Mr.Dinesh Naik', 'Mr.Hiren Daftardar', 'Ms.Anita Naik', 'Mr.Prasad Gharat']

# %%
pdf = open("workingpaper.pdf","rb")
pdf_reader = PyPDF2.PdfReader(pdf)
print("Number of pages:",len(pdf_reader.pages))
page = pdf_reader.pages[1]
print(page.extract_text())
pdf.close()
# Out:
# Number of pages: 35
#
#
#  Development  Plan for Greater Mumbai 2014‐2034
# Acknowledgements
# The Consultant  wishes to thank the following  individuals  from the Municipal  Corporation  of
# Greater Mumbai for their invaluable  support, insights and contributions  towards ‘Working  Paper 1
# – Preparation  of Base Map’ for the preparation  of the Development  Plan for Greater Mumbai
# 2014‐34.
#  Mr. Subodh Kumar, IAS, Municipal  Commissioner;
#  Mr. Rajeev Kuknoor, Chief Engineer Development  Plan;
#  Mr. Sudhir Ghate, Deputy Chief Engineer Development  Plan;
#  Mr. A.G. Marathe, Deputy Chief Engineer Development  Plan;
#  Mr. R. Balachandran,  Executive  Engineer and Town Planning Officer, Development  Plan.
#  Our gratitude  to the following  experts for their invaluable  insights and support:
# 
# Mr. V.K Phatak, Former Chief Town Planner (MMRDA);
#  Mr. A.N Kale, Former Chief Engineer, (DP);
#  Mr. A. S Jain Former Dy. Chief Engineer, (DP).
#  We wish to especially  thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren
# Daftardar,  Ms. Anita Naik for their continual  support since the
#  beginning  of the project and their
# help towards familiarization  and data collection.  They have been instrumental  in helping to
# contact various MCGM departments  as well as in helping to establish contact with personnel  from
# other government  departments  and organizations.  Many thanks for the MCGM team, for
# deploying  personnel,  particularly  Mr. Prasad Gharat, on extensive  field visits that have helped in
# understanding  actual ground conditions.
#
# We apologize  if we have inadvertently  omitted anyone to whom acknowledgement  is due. We hope
# and anticipate  the work's usefulness  for the intended purpose.

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in d:\users\saisagar\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in d:\users\saisagar\anaconda3\lib\site-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/244.3 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/244.3 kB 435.7 kB/s eta 0:00:01
#    -------------- ------------------------ 92.2/244.3 kB 871.5 kB/s eta 0:00:01
#    ------------------------------------ --- 225.3/244.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 244.3/244.3 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
import docx

# %%
doc=open("workingpaper1.docx","rb")
document=docx.Document(doc)

# %%
docu=""
for para in document.paragraphs:
    docu +=para.text
print(docu)
# Out:
# Development Plan for Greater Mumbai 2014‐2034AcknowledgementsThe Consultant wishes to thank the following individuals from the Municipal Corporation of Greater Mumbai for their invaluable support, insights and contributions towards ‘Working Paper 1 – Preparation of Base Map’ for the preparation of the Development Plan for Greater Mumbai 2014‐34.Mr. Subodh Kumar, IAS, Municipal Commissioner;Mr. Rajeev Kuknoor, Chief Engineer Development Plan;Mr. Sudhir Ghate, Deputy Chief Engineer Development Plan;Mr. A.G. Marathe, Deputy Chief Engineer Development Plan;Mr. R. Balachandran, Executive Engineer and Town Planning Officer, Development Plan.Our gratitude to the following experts for their invaluable insights and support:Mr. V.K Phatak, Former Chief Town Planner (MMRDA);Mr. A.N Kale, Former Chief Engineer, (DP);Mr. A. S Jain Former Dy. Chief Engineer, (DP).We wish to especially thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren Daftardar, Ms. Anita Naik for their continual support since the beginning of the project and their help towards familiarization and data collection. They have been instrumental in helping to contact various MCGM departments as well as in helping to establish contact with personnel from other government departments and organizations. Many thanks for the MCGM team, for deploying personnel, particularly Mr. Prasad Gharat, on extensive field visits that have helped in understanding actual ground conditions.We apologize if we have inadvertently omitted anyone to whom acknowledgement is due. We hope and anticipate the work's usefulness for the intended purpose.Development Plan for Greater Mumbai 2014‐2034Table of ContentsList of FiguresAbbreviationsMCGM	Municipal Corporation of Greater MumbaiMUTP	Mumbai Urban Transport ProjectMTHL	Mumbai Trans Harbour LinkMMR	Mumbai Metropolitan RegionMHADA	Maharashtra Housing and Area Development AuthorityMPCB	Maharashtra Pollution Control BoardPLU	Proposed Land useSWOT	Strengths Weaknesses Opportunities ThreatsToR	Terms of ReferenceIntroductionThe primary purpose of a Base Map is to provide general information about spatial patterns, provide specific information about particular locations, while serving as a base for overlaying various layers of information, spatial and non‐spatial. The Base Map is a crucial output of the GIS database. It provides essential information that forms the basis of all further data layers that are added to form the complete database. Typically a Base Map would involve a geo‐referenced satellite image over which various data layers are superimposed to form GIS database for Base Map. The objective of the creation of a Base Map of acceptable accuracy is to facilitate preparation of the Development Plan for Mumbai 2034. In this context, the Base Map will serve as the underlying reference for the GIS database. This database, then serves further purposes of Existing Land Use Surveys and Mapping, future additional layer overlays for urban planning analysis including existing situation analysis and ongoing and proposed projects, sectoral thematic mapping, scenario building. This finally leads to the Proposed Land Use Maps that form the Development Plan for Mumbai 2034.Data available has been assessed In terms of data quality received and gaps in the data identified. The Way Forward suggests methods as mutually discussed between Consultant and MCGM during weekly meetings to fast track corrections and proceed with GIS data base and Base Map preparation.Data made available for Preparation of Base Map by MCGMThe spatial data for preparation of this Base Map and GIS Database is the data received from MCGM on 19.05.2011. Projections system used is WGS_1984_UTM_Zone_43N.The spatial data that MCGM has provided includes GIS data for all the 24 wards within its jurisdiction MCGM has also provided additional data in its possession relevant to the project. Some of the data that has been provided is in CAD vector format which needs geo‐referencing first to ...

# %%
for i in range(len(document.paragraphs)):
    print("The content of the paragraph "+ str(i)+" is : "+document.paragraphs[i].text+"\n" )
# Out:
# The content of the paragraph 0 is :
#
# The content of the paragraph 1 is :
#
# The content of the paragraph 2 is :
#
# The content of the paragraph 3 is :
#
# The content of the paragraph 4 is :
#
# The content of the paragraph 5 is :
#
# The content of the paragraph 6 is :
#
# The content of the paragraph 7 is :
#
# The content of the paragraph 8 is :
#
# The content of the paragraph 9 is :
#
# The content of the paragraph 10 is :
#
# The content of the paragraph 11 is :
#
# The content of the paragraph 12 is :
#
# The content of the paragraph 13 is :
#
# The content of the paragraph 14 is :
#
# The content of the paragraph 15 is :
#
# The content of the paragraph 16 is :
#
# The content of the paragraph 17 is :
#
# The content of the paragraph 18 is :
#
# The content of the paragraph 19 is :
#
# The content of the paragraph 20 is :
#
# The content of the paragraph 21 is :
#
# The content of the paragraph 22 is :
#
# The content of the paragraph 23 is :
#
# The content of the paragraph 24 is :
#
# The content of the paragraph 25 is :
#
# The content of the paragraph 26 is :
#
# The content of the paragraph 27 is :
#
# The content of the paragraph 28 is :
#
# The content of the paragraph 29 is :
#
# The content of the paragraph 30 is :
#
# The content of the paragraph 31 is :
#
# The content of the paragraph 32 is :
#
# The content of the paragraph 33 is :
#
# The content of the paragraph 34 is :
#
# The content of the paragraph 35 is :
#
# The content of the paragraph 36 is :
#
# The content of the paragraph 37 is :
#
# The content of the paragraph 38 is :
#
# The content of the paragraph 39 is :
#
# The content of the paragraph 40 is :
#
# The content of the paragraph 41 is :
#
# The content of the paragraph 42 is :
#
# The content of the paragraph 43 is :
#
# The content of the paragraph 44 is :
#
# The content of the paragraph 45 is :
#
# The content of the paragraph 46 is :
#
# The content of the paragraph 47 is :
#
# The content of the paragraph 48 is :
#
# The content of the paragraph 49 is :
#
# The content of the paragraph 50 is :
#
# The content of the paragraph 51 is :
#
# The content of the paragraph 52 is :
#
# The content of the paragraph 53 is :
#
# The content of the paragraph 54 is :
#
# The content of the paragraph 55 is :
#
# The content of the paragraph 56 is :
#
# The content of the paragraph 57 is :
#
# The content of the paragraph 58 is :
#
# The content of the paragraph 59 is : Development Plan for Greater Mumbai 2014‐2034
#
# The content of the paragraph 60 is :
#
# The content of the paragraph 61 is : Acknowledgements
#
# The content of the paragraph 62 is :
#
# The content of the paragraph 63 is : The Consultant wishes to thank the following individuals from the Municipal Corporation of Greater Mumbai for their invaluable support, insights and contributions towards ‘Working Paper 1 – Preparation of Base Map’ for the preparation of the Development Plan for Greater Mumbai 2014‐34.
#
# The content of the paragraph 64 is : Mr. Subodh Kumar, IAS, Municipal Commissioner;
#
# The content of the paragraph 65 is : Mr. Rajeev Kuknoor, Chief Engineer Development Plan;
#
# The content of the paragraph 66 is : Mr. Sudhir Ghate, Deputy Chief Engineer Development Plan;
#
# The content of the paragraph 67 is : Mr. A.G. Marathe, Deputy Chief Engineer Development Plan;
#
# The content of the paragraph 68 is : Mr. R. Balachandran, Executive Engineer and Town Planning Officer, Development Plan.
#
# The content of the paragraph 69 is :
#
# The content of the paragraph 70 is : Our gratitude to the following experts for their invaluable insights and support:
#
# The content of the paragraph 71 is : Mr. V.K Phatak, Former Chief Town Planner (MMRDA);
#
# The content of the paragraph 72 is : Mr. A.N Kale, Former Chief Engineer, (DP);
#
# The content of the paragraph 73 is : Mr. A. S Jain Former Dy. Chief Engineer, (DP).
#
# The content of the paragraph 74 is :
#
# The content of the paragraph 75 is : We wish to especially thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren Daftardar, Ms. Anita Naik for their continual support since the beginning of the project and their help towards familiarization and data collection. They have been instrumental in helping to contact various MCGM departments as well as in helping to establish contact with personnel from other government departments and organizations. Many thanks for the MCGM team, for deploying personnel, particularly Mr. Prasad Gharat, on extensive field visits that have helped in understanding actual ground conditions.
#
# The content of the paragraph 76 is :
#
# The content of the paragraph 77 is : We apologize if we have inadvertently omitted anyone to whom acknowledgement is due. We hope and anticipate the work's usefulness for the intended purpose.
#
# The content of the paragraph 78 is :
#
# The content of the paragraph 79 is :
#
# The content of the paragraph 80 is :
#
# The content of the paragraph 81 is :
#
# The content of the paragraph 82 is :
#
# The content of the paragraph 83 is :
#
# The content of the paragraph 84 is :
#
# The content of the paragraph 85 is :
#
# The content of the paragraph 86 is :
#
# The content of the paragraph 87 is :
#
# The content of the paragraph 88 is :
#
# The content of the paragraph 89 is :
#
# The content of the paragraph 90 is :
#
# The content of the paragraph 91 is :
#
# The content of the paragraph 92 is :
#
# The content of the paragraph 93 is : Development Plan for Greater Mumbai 2014‐2034
#
# The content of the paragraph 94 is :
#
# The content of the paragraph 95 is : Table of Contents
#
# The content of the paragraph 96 is :
#
# The content of the paragraph 97 is :
#
# The content of the paragraph 98 is : List of Figures
#
# The content of the paragraph 99 is :
#
# The content of the paragraph 100 is : Abbreviations
#
# The content of the paragraph 101 is : MCGM	Municipal Corporation of Greater Mumbai
#
# The content of the paragraph 102 is :
#
# The content of the paragraph 103 is : MUTP	Mumbai Urban Transport Project
#
# The content of the paragraph 104 is :
#
# The content of the paragraph 105 is : MTHL	Mumbai Trans Harbour Link
#
# The content of the paragraph 106 is :
#
# The content of the paragraph 107 is : MMR	Mumbai Metropolitan Region
#
# The content of the paragraph 108 is :
#
# The content of the paragraph 109 is : MHADA	Maharashtra Housing and Area Development Authority
#
# The content of the paragraph 110 is :
#
# The content of the paragraph 111 is : MPCB	Maharashtra Pollution Control Board
#
# The content of the paragraph 112 is : PLU	Proposed Land use
#
# The content of the paragraph 113 is :
#
# The content of the paragraph 114 is : SWOT	Strengths Weaknesses Opportunities Threats
#
# The content of the paragraph 115 is :
#
# The content of the paragraph 116 is : ToR	Terms of Reference
#
# The content of the paragraph 117 is :
#
# The content of the paragraph 118 is : Introduction
#
# The content of the paragraph 119 is :
#
# The content of the paragraph 120 is : The primary purpose of a Base Map is to provide general information about spatial patterns, provide specific information about particular locations, while serving as a base for overlaying various layers of information, spatial and non‐spatial. The Base Map is a crucial output of the GIS database. It provides essential information that forms the basis of all further data layers that are added to form the complete database. Typically a Base Map would involve a geo‐referenced satellite image over which various data layers are superimposed to form GIS database for Base Map.
#
# The content of the paragraph 121 is : The objective of the creation of a Base Map of acceptable accuracy is to facilitate preparation of the Development Plan for Mumbai 2034. In this context, the Base Map will serve as the underlying reference for the GIS database. This database, then serves further purposes of Existing Land Use Surveys and Mapping, future additional layer overlays for urban planning analysis including existing situation analysis and ongoing and proposed projects, sectoral thematic mapping, scenario building. This finally leads to the Proposed Land Use Maps that form the Development Plan for Mumbai 2034.
#
# The content of the paragraph 122 is : Data available has been assessed In terms of data quality received and gaps in the data identified. The Way Forward suggests methods as mutually discussed between Consultant and MCGM during weekly meetings to fast track corrections and proceed with GIS data base and Base Map preparation.
#
# The content of the paragraph 123 is :
#
# The content of the paragraph 124 is : Data made available for Preparation of Base Map by MCGM
#
# The content of the paragraph 125 is : The spatial data for preparation of this Base Map and GIS Database is the data received from MCGM on 19.05.2011. Projections system used is WGS_1984_UTM_Zone_43N.
#
# The content of the paragraph 126 is : The spatial data that MCGM has provided includes GIS data for all the 24 wards within its jurisdiction MCGM has also provided additional data in its possession relevant to the project. Some of the data that has been provided is in CAD vector format which needs geo‐referencing first to extract relevant information.
#
# The content of the paragraph 127 is :
#
# The content of the paragraph 128 is : Quick Bird satellite image handed over by MCGM
#
# The content of the paragraph 129 is : A Quick Bird High resolution satellite image has been provided by MCGM for the scope of the project. MCGM had already got this image geo‐referenced during their GIS creation exercise. On the basis of the discussions during the weekly meetings with MCGM, it has been assumed that this satellite image provided by MCGM is of acceptable accuracy for the preparation of the Base Map for the ELU Surveys and the preparation of the Development Plan.
#
# The content of the paragraph 130 is :
#
# The content of the paragraph 131 is : 1.
#
# The content of the paragraph 132 is :
#
# The content of the paragraph 133 is : Digitized Tikka Sheets (Shape Files)
#
# The content of the paragraph 134 is : The MCGM has handed over digital data pertaining to 1:500 Tikka sheets. These sheets have been scanned, digitized and converted into GIS vector layers. The digitized data has been placed over the geo‐referenced Quick Bird Image to achieve a good reference. Since geo‐referencing of Quick Bird image has already been carried out by MCGM at the level of accuracy acceptable to MCGM, it is therefore assumed that this digitized Tikka data provided by MCGM is of acceptable accuracy for the preparation of the Base Map for the ELU Surveys and the preparation of the Development Plan.
#
# The content of the paragraph 135 is :
#
# The content of the paragraph 136 is : Figure : Sample Base Map – 1 generated from MCGM database
#
# The content of the paragraph 137 is :
#
# The content of the paragraph 138 is : Figure : Sample Base Map – 2 generated from MCGM database
#
# The content of the paragraph 139 is :
#
# The content of the paragraph 140 is : Other Data Layers forming present Development Plan (Shape Files)
#
# The content of the paragraph 141 is : The MCGM database provided has a number of layers pertaining to spatial data for each of the 24 wards. These layers contain various features such as roads, buildings, nallas etc. It also contains cadastral information related to individual parcels of land. A complete ward‐wise listing of the various layers in the database is provided in the Inception Report Appendix. Other details are as indicated below:
#
# The content of the paragraph 142 is :
#
# The content of the paragraph 143 is :
#
# The content of the paragraph 144 is : Components of Base Map
#
# The content of the paragraph 145 is : The Base map is formed through a series of overlays of spatial data layers as provided by MCGM on a base layer which is the Quick Bird image.
#
# The content of the paragraph 146 is :
#
# The content of the paragraph 147 is : Base layer
#
# The content of the paragraph 148 is :
#
# The content of the paragraph 149 is : The Quick Bird high resolution satellite image (0.61m accuracy) of the MCGM jurisdiction that has been provided by MCGM will form the base layer of the Base Map.
#
# The content of the paragraph 150 is :
#
# The content of the paragraph 151 is :
#
# The content of the paragraph 152 is :
#
# The content of the paragraph 153 is :
#
# The content of the paragraph 154 is :
#
# The content of the paragraph 155 is :
#
# The content of the paragraph 156 is :
#
# The content of the paragraph 157 is :
#
# The content of the paragraph 158 is :
#
# The content of the paragraph 159 is :
#
# The content of the paragraph 160 is :
#
# The content of the paragraph 161 is :
#
# The content of the paragraph 162 is :
#
# The content of the paragraph 163 is :
#
# The content of the paragraph 164 is :
#
# The content of the paragraph 165 is :
#
# The content of the paragraph 166 is : Figure : Quick Bird Satellite Image as provded by MCGM
#
# The content of the paragraph 167 is :
#
# The content of the paragraph 168 is : Data layers
#
# The content of the paragraph 169 is :
#
# The content of the paragraph 170 is : Over the Quick Bird satellite image of the area under MCGM, several layers available in the database provided by MCGM will be used as overlays to create the Base Map. Layers pertaining to jurisdictional boundaries/ administrative boundaries and special planning areas (under MMRDA and MIDC) will be overlaid. Layers pertaining to natural features like forests, water bodies, hills are essential overlays and shall be extracted from the given data base. Further, layers pertaining to transportation networks (airport, railways and roads) and cadastral parcels will be overlaid.
#
# The content of the paragraph 171 is : From the database provided by MCGM, along with the Quick Bird satellite image the following layers will be used to create the Base Map:
#
# The content of the paragraph 172 is : Jurisdiction boundaries: Ward boundaries and other boundaries of spatial disaggregation special planning areas, TP Schemes;
#
# The content of the paragraph 173 is : Physical features: Street blocks, buildings, property (cadastral parcels);
#
# The content of the paragraph 174 is : Transportation: Roads, road centrelines, rail roads, transportation infrastructure parcels, railway stations, airport boundary, highways, water based transportation facilities, BEST bus Depot/bus stations;
#
# The content of the paragraph 175 is : Utility infrastructure: High tension lines, water pipelines (visible above ground);
#
# The content of the paragraph 176 is : Environmentally sensitive areas: National park, nallas, water bodies etc.
#
# The content of the paragraph 177 is :
#
# The content of the paragraph 178 is :
#
# The content of the paragraph 179 is :
#
# The content of the paragraph 180 is : Data to be updated
#
# The content of the paragraph 181 is :
#
# The content of the paragraph 182 is : Data regarding natural features is not readily available in the data layers provided. Since water bodies sometimes alter courses over time updated data related to water bodies, such as rivers and lakes will be obtained from the Quick Bird satellite image provided. Similarly information regarding hills will be obtained from Contour data which will be provided by the MCGM. Further, updating of the available Base Map layers such as road and road centerlines will also be done based on the Quick Bird Image provided.
#
# The content of the paragraph 183 is : The Base Map prepared by the process detailed below will form the base for the Existing Landuse Map. For the MCGM limits the available Base Map has been obtained from the Tikka sheet of 1960’s where all the available layers have been digitized at the scale of 1:500. Quick Bird satellite image which (according to Digital Globe, the provider of these satellite images) is meant for a scale of 1: 5,000 was used to geo‐reference the Tikka sheets. Therefore the positional accuracy of the Tikka data corresponds to the geo‐referenced satellite image. The digitized scale of 1:500 remains unchanged for the Base Map.
#
# The content of the paragraph 184 is :
#
# The content of the paragraph 185 is :
#
# The content of the paragraph 186 is :
#
# The content of the paragraph 187 is :
#
# The content of the paragraph 188 is :
#
# The content of the paragraph 189 is :
#
# The content of the paragraph 190 is :
#
# The content of the paragraph 191 is :
#
# The content of the paragraph 192 is :
#
# The content of the paragraph 193 is :
#
# The content of the paragraph 194 is :
#
# The content of the paragraph 195 is :
#
# The content of the paragraph 196 is :
#
# The content of the paragraph 197 is :
#
# The content of the paragraph 198 is :
#
# The content of the paragraph 199 is :
#
# The content of the paragraph 200 is :
#
# The content of the paragraph 201 is :
#
# The content of the paragraph 202 is :
#
# The content of the paragraph 203 is :
#
# The content of the paragraph 204 is :
#
# The content of the paragraph 205 is :
#
# The content of the paragraph 206 is :
#
# The content of the paragraph 207 is :
#
# The content of the paragraph 208 is :
#
# The content of the paragraph 209 is : Figure : Base Map Preparation Process
#
# The content of the paragraph 210 is :
#
# The content of the paragraph 211 is :
#
# The content of the paragraph 212 is :
#
# The content of the paragraph 213 is :
#
# The content of the paragraph 214 is : Figure : Diagram of Base Map Preparation Process
#
# The content of the paragraph 215 is :
#
# The content of the paragraph 216 is : Quality of Data Received
#
# The content of the paragraph 217 is : Background
#
# The content of the paragraph 218 is :
#
# The content of the paragraph 219 is : The main objective of this data assessment is to verify the quality of the GIS data handed over by MCGM to the Consultant. The data is checked for its quality with respect to overlay (over the Quick Bird image given by the MCGM), presence of data in all the given layers, attribute information regarding features present, overlay with respect to other available layers and topology issues.
#
# The content of the paragraph 220 is : The Base Map layers given by the MCGM contains data for all the 24 wards. However the data is not of same quality in terms of overlay, topology and availability of the data in the layer files. There are also issues related to attributes such as nomenclature, field information and presence of null values in the attribute tables. Please refer to the Inception Report Annexure on quality of data.
#
# The content of the paragraph 221 is : There is a major shift ranging from 14 ‐ 60 meters for 6 of the wards which needs to be corrected and brought back to its location using the available Quick Bird Image which is of 0.61 m resolution or preferably through DGPS control points. The high resolution satellite image is a vintage image and does not reflect the latest ground reality. The Base Map shall be updated to reflect the ground reality by updating the layers based on the ELU survey, Google Earth image and other field surveys.
#
# The content of the paragraph 222 is :
#
# The content of the paragraph 223 is : GIS Issues and their resolution
#
# The content of the paragraph 224 is :
#
# The content of the paragraph 225 is : Seven types of issues are highlighted here:
#
# The content of the paragraph 226 is : Quick Bird Image
#
# The content of the paragraph 227 is : The Quick Bird image appears cropped short of the MCGM jurisdictional boundary and is incomplete. As a result, there is a minimal loss of data around the coastal edges and at the borders of the jurisdiction of the MCGM. The Quick Bird image 2007‐08 of the MMRDA once provided will be utilized by the consultants for updating the data base in the missing areas of the MCGM Quick Bird image.
#
# The content of the paragraph 228 is :
#
# The content of the paragraph 229 is :
#
# The content of the paragraph 230 is :
#
# The content of the paragraph 231 is :
#
# The content of the paragraph 232 is :
#
# The content of the paragraph 233 is :
#
# The content of the paragraph 234 is :
#
# The content of the paragraph 235 is :
#
# The content of the paragraph 236 is :
#
# The content of the paragraph 237 is :
#
# The content of the paragraph 238 is :
#
# The content of the paragraph 239 is :
#
# The content of the paragraph 240 is :
#
# The content of the paragraph 241 is :
#
# The content of the paragraph 242 is :
#
# The content of the paragraph 243 is :
#
# The content of the paragraph 244 is :
#
# The content of the paragraph 245 is :
#
# The content of the paragraph 246 is :
#
# The content of the paragraph 247 is :
#
# The content of the paragraph 248 is :
#
# The content of the paragraph 249 is :
#
# The content of the paragraph 250 is :
#
# The content of the paragraph 251 is :
#
# The content of the paragraph 252 is :
#
# The content of the paragraph 253 is :
#
# The content of the paragraph 254 is :
#
# The content of the paragraph 255 is :
#
# The content of the paragraph 256 is :
#
# The content of the paragraph 257 is :
#
# The content of the paragraph 258 is :
#
# The content of the paragraph 259 is :
#
# The content of the paragraph 260 is :
#
# The content of the paragraph 261 is :
#
# The content of the paragraph 262 is :
#
# The content of the paragraph 263 is :
#
# The content of the paragraph 264 is : Figure : Quick Bird image 2007‐08 indicating cropped edges short of the MCGM Boundary
#
# The content of the paragraph 265 is :
#
# The content of the paragraph 266 is : Shift in data layers
#
# The content of the paragraph 267 is : When the data layer was overlaid over the Quick Bird satellite image, it was noticed that in the case of 6 wards there is a significant shift in the entire data nearly ranging from 19m to 55m. MCGM has asked the Consultant to rectify the errors and shift the data layers back as accurately as possible.
#
# The content of the paragraph 268 is :
#
# The content of the paragraph 269 is :
#
# The content of the paragraph 270 is :
#
# The content of the paragraph 271 is :
#
# The content of the paragraph 272 is :
#
# The content of the paragraph 273 is :
#
# The content of the paragraph 274 is :
#
# The content of the paragraph 275 is :
#
# The content of the paragraph 276 is :
#
# The content of the paragraph 277 is :
#
# The content of the paragraph 278 is :
#
# The content of the paragraph 279 is :
#
# The content of the paragraph 280 is :
#
# The content of the paragraph 281 is :
#
# The content of the paragraph 282 is :
#
# The content of the paragraph 283 is :
#
# The content of the paragraph 284 is : Figure : Example of Ward F/N wherein property boundaries are not matching with Quick Bird
#
# The content of the paragraph 285 is :
#
# The content of the paragraph 286 is :
#
# The content of the paragraph 287 is : On trying to rectify the data it was found that the data not only requires a shift but also some rotation to have as precise an overlay as possible with visual correction. It has been discussed with the MCGM that this visual correction may entail an error of 3m‐8m. There is a risk of creating overlaps/gaps between different wards datasets (since the data has not been merged into one dataset). These gaps/ overlaps would be left as such since these tasks correspond to a land titling/ cadastral project which is beyond the scope of this project.
#
# The content of the paragraph 288 is : The Consultant is correcting the data to the extent possible after discussion with MCGM to achieve a level of acceptable accuracy.
#
# The content of the paragraph 289 is :
#
# The content of the paragraph 290 is : In wards H/E, K/W, P, R, S, T where there seems to be a data shift, there continues to be edge matching issues, even after the initial task of repositioning and relocating it back to its original position. A methodology mutually agreed between Consultant and MCGM will be adopted to resolve this.
#
# The content of the paragraph 291 is :
#
# The content of the paragraph 292 is :
#
# The content of the paragraph 293 is :
#
# The content of the paragraph 294 is :
#
# The content of the paragraph 295 is : Figure : Edge matching Issues
#
# The content of the paragraph 296 is :
#
# The content of the paragraph 297 is :
#
# The content of the paragraph 298 is :
#
# The content of the paragraph 299 is : New buildings
#
# The content of the paragraph 300 is : New buildings are found to be missing in all the wards since the data is extracted from old Tikka Sheets. These will be updated by the Consultants based on methodology agreed with MCGM.
#
# The content of the paragraph 301 is :
#
# The content of the paragraph 302 is :
#
# The content of the paragraph 303 is :
#
# The content of the paragraph 304 is :
#
# The content of the paragraph 305 is :
#
# The content of the paragraph 306 is :
#
# The content of the paragraph 307 is :
#
# The content of the paragraph 308 is :
#
# The content of the paragraph 309 is :
#
# The content of the paragraph 310 is : Figure 9: Example of Ward B wherein new buildings are not present and will be updated with methodology agreed mutually
#
# The content of the paragraph 311 is : Ward boundaries
#
# The content of the paragraph 312 is : The ward boundary layer given by MCGM will be treated as final. Wards M and R are shown as single entities and further subdivisions into M/E, M/W, R/N, R/S, R/C are not shown. The consultant will work with MCGM for delineation of the current status of boundaries.
#
# The content of the paragraph 313 is :
#
# The content of the paragraph 314 is :
#
# The content of the paragraph 315 is : Figure 10: Example of Ward R shown as a single entity without sub divisions
#
# The content of the paragraph 316 is :
#
# The content of the paragraph 317 is :
#
# The content of the paragraph 318 is : Topology
#
# The content of the paragraph 319 is : The data also has topology errors such as overlaps, undershoots, and pseudo nodes. These have to be corrected by the Consultant with help from the MCGM.
#
# The content of the paragraph 320 is :
#
# The content of the paragraph 321 is :
#
# The content of the paragraph 322 is :
#
# The content of the paragraph 323 is :
#
# The content of the paragraph 324 is :
#
# The content of the paragraph 325 is :
#
# The content of the paragraph 326 is :
#
# The content of the paragraph 327 is :
#
# The content of the paragraph 328 is :
#
# The content of the paragraph 329 is :
#
# The content of the paragraph 330 is :
#
# The content of the paragraph 331 is :
#
# The content of the paragraph 332 is :
#
# The content of the paragraph 333 is :
#
# The content of the paragraph 334 is :
#
# The content of the paragraph 335 is :
#
# The content of the paragraph 336 is :
#
# The content of the paragraph 337 is :
#
# The content of the paragraph 338 is : Figure : Example of Ward C with topology errors
#
# The content of the paragraph 339 is :
#
# The content of the paragraph 340 is :
#
# The content of the paragraph 341 is :
#
# The content of the paragraph 342 is :
#
# The content of the paragraph 343 is :
#
# The content of the paragraph 344 is :
#
# The content of the paragraph 345 is :
#
# The content of the paragraph 346 is :
#
# The content of the paragraph 347 is :
#
# The content of the paragraph 348 is :
#
# The content of the paragraph 349 is :
#
# The content of the paragraph 350 is :
#
# The content of the paragraph 351 is :
#
# The content of the paragraph 352 is :
#
# The content of the paragraph 353 is : Figure : Topology Errors with reference to Property Layer, example of Ward K/W with topology errors
#
# The content of the paragraph 354 is :
#
# The content of the paragraph 355 is :
#
# The content of the paragraph 356 is :
#
# The content of the paragraph 357 is :
#
# The content of the paragraph 358 is :
#
# The content of the paragraph 359 is : Attribute Info
#
# The content of the paragraph 360 is : The naming of layers does not follow the Nomenclature of having the first letter in capitals; the layers are not named as per standard GIS nomenclature with each layer having its own name and property. Some of the Attribute layers are not completely filled and has lot of missing information.
#
# The content of the paragraph 361 is : Attribute data is found missing for some layers, for example, the layer Layout properties, the CTS_CS_No along with village name and division are not complete. The Consultant will not modify cadastral data and will use it as is. The time required for modification will be intimated to MCGM.
#
# The content of the paragraph 362 is :
#
# The content of the paragraph 363 is :
#
# The content of the paragraph 364 is : Figure : Issues related to nomenclature of feature classes
#
# The content of the paragraph 365 is :
#
# The content of the paragraph 366 is :
#
# The content of the paragraph 367 is :
#
# The content of the paragraph 368 is :
#
# The content of the paragraph 369 is :
#
# The content of the paragraph 370 is :
#
# The content of the paragraph 371 is :
#
# The content of the paragraph 372 is :
#
# The content of the paragraph 373 is :
#
# The content of the paragraph 374 is :
#
# The content of the paragraph 375 is :
#
# The content of the paragraph 376 is :
#
# The content of the paragraph 377 is :
#
# The content of the paragraph 378 is :
#
# The content of the paragraph 379 is :
#
# The content of the paragraph 380 is :
#
# The content of the paragraph 381 is :
#
# The content of the paragraph 382 is :
#
# The content of the paragraph 383 is :
#
# The content of the paragraph 384 is :
#
# The content of the paragraph 385 is :
#
# The content of the paragraph 386 is :
#
# The content of the paragraph 387 is :
#
# The content of the paragraph 388 is : Figure : Issues related to attribute table
#
# The content of the paragraph 389 is :
#
# The content of the paragraph 390 is :
#
# The content of the paragraph 391 is :
#
# The content of the paragraph 392 is :
#
# The content of the paragraph 393 is :
#
# The content of the paragraph 394 is : There is a difference in field characteristics in the attribute data for different wards; for example, it has a short integer for ward H/W for the filled Bldg id, it is a string for the same field in ward K/E and in ward M and N the field has long integer as its character. This causes a problem in uploading of data
#
# The content of the paragraph 395 is :
#
# The content of the paragraph 396 is : into a single database where it is necessary to have common properties for all the fields to load it into a single database. Time required for the same will be intimated to MCGM.
#
# The content of the paragraph 397 is :
#
# The content of the paragraph 398 is :
#
# The content of the paragraph 399 is :
#
# The content of the paragraph 400 is :
#
# The content of the paragraph 401 is : Figure : Issues related to Attribute Field Characteristics
#
# The content of the paragraph 402 is :
#
# The content of the paragraph 403 is :
#
# The content of the paragraph 404 is :
#
# The content of the paragraph 405 is : Summary Assessment Matrix for GIS Data for each of the wards
#
# The content of the paragraph 406 is :
#
# The content of the paragraph 407 is : Summary Assessment Matrix for GIS Data for each of the wards
#
# The content of the paragraph 408 is : Projection System used:
#
# The content of the paragraph 409 is : WGS_1984_UTM_ZONE_43N
#
# The content of the paragraph 410 is : Sl no  Ward Name	Global view of Topology errors	Example of Topology error
#
# The content of the paragraph 411 is : Ward A
#
# The content of the paragraph 412 is : Total No of layers: 59
#
# The content of the paragraph 413 is : No of layers with data: 35 Total Topology errors: 484 Gaps: 450
#
# The content of the paragraph 414 is : Overlap: 34
#
# The content of the paragraph 415 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 416 is :
#
# The content of the paragraph 417 is :
#
# The content of the paragraph 418 is : Ward B
#
# The content of the paragraph 419 is : Total No of layers: 60
#
# The content of the paragraph 420 is : No of layers with data: 37 Total Topology errors: 274 Gaps: 273
#
# The content of the paragraph 421 is : Overlap: 1
#
# The content of the paragraph 422 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 423 is :
#
# The content of the paragraph 424 is : Ward C
#
# The content of the paragraph 425 is : Total No of layers: 59
#
# The content of the paragraph 426 is : No of layers with data: 29 Total Topology errors: 288 Gaps: 286
#
# The content of the paragraph 427 is : Overlap: 22
#
# The content of the paragraph 428 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 429 is :
#
# The content of the paragraph 430 is : Ward D
#
# The content of the paragraph 431 is : Total No of layers: 60
#
# The content of the paragraph 432 is : No of layers with data: 34 Total Topology errors: 170 Gaps: 159
#
# The content of the paragraph 433 is : Overlap: 11
#
# The content of the paragraph 434 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 435 is :
#
# The content of the paragraph 436 is : Ward E
#
# The content of the paragraph 437 is : Total No of layers: 59
#
# The content of the paragraph 438 is : No of layers with data: 32 Total Topology errors: 269 Gaps: 258
#
# The content of the paragraph 439 is : Overlap: 11
#
# The content of the paragraph 440 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 441 is :
#
# The content of the paragraph 442 is : Ward F/N
#
# The content of the paragraph 443 is : Total No of layers: 59
#
# The content of the paragraph 444 is : No of layers with data: 32 Total Topology errors: 155 Gaps: 126
#
# The content of the paragraph 445 is : Overlap: 29
#
# The content of the paragraph 446 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 447 is :
#
# The content of the paragraph 448 is : Ward F/S
#
# The content of the paragraph 449 is : Total No of layers: 60
#
# The content of the paragraph 450 is : No of layers with data: 32 Total Topology errors: 116 Gaps: 98
#
# The content of the paragraph 451 is : Overlap: 18
#
# The content of the paragraph 452 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 453 is : Ward G/N
#
# The content of the paragraph 454 is : Total No of layers: 60
#
# The content of the paragraph 455 is : No of layers with data: 43 Total Topology errors: 86 Gaps: 75
#
# The content of the paragraph 456 is : Overlap: 11
#
# The content of the paragraph 457 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 458 is :
#
# The content of the paragraph 459 is : Ward G/S
#
# The content of the paragraph 460 is : Total No of layers: 60
#
# The content of the paragraph 461 is : No of layers with data: 43 Total Topology errors: 62 Gaps: 60
#
# The content of the paragraph 462 is : Overlap: 2
#
# The content of the paragraph 463 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 464 is : Ward H/E
#
# The content of the paragraph 465 is : Total No of layers: 61
#
# The content of the paragraph 466 is : No of layers with data: 46 Total Topology errors: 317 Gaps: 303
#
# The content of the paragraph 467 is : Overlap: 14
#
# The content of the paragraph 468 is : Overlay status (As per Quick Bird image from MCGM): Shift of 55 meters
#
# The content of the paragraph 469 is : Ward H/W
#
# The content of the paragraph 470 is : Total No of layers: 62
#
# The content of the paragraph 471 is : No of layers with data: 50 Total Topology errors: 746 Gaps: 734
#
# The content of the paragraph 472 is : Overlap: 12
#
# The content of the paragraph 473 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 474 is :
#
# The content of the paragraph 475 is : Ward K/E
#
# The content of the paragraph 476 is : Total No of layers: 60
#
# The content of the paragraph 477 is : No of layers with data: 47 Total Topology errors: 366 Gaps: 268
#
# The content of the paragraph 478 is : Overlap: 98
#
# The content of the paragraph 479 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 480 is :
#
# The content of the paragraph 481 is :
#
# The content of the paragraph 482 is :
#
# The content of the paragraph 483 is : Ward K/W
#
# The content of the paragraph 484 is : Total No of layers: 61
#
# The content of the paragraph 485 is : No of layers with data: 49 Total Topology errors: 841 Gaps: 548
#
# The content of the paragraph 486 is : Overlap: 266
#
# The content of the paragraph 487 is : Overlay status (As per Quick Bird image from MCGM): Shift of 55 meters
#
# The content of the paragraph 488 is : Ward L
#
# The content of the paragraph 489 is : Total No of layers: 62
#
# The content of the paragraph 490 is : No of layers with data: 34 Total Topology errors: 461 Gaps: 382
#
# The content of the paragraph 491 is : Overlap: 79
#
# The content of the paragraph 492 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 493 is :
#
# The content of the paragraph 494 is : Ward M
#
# The content of the paragraph 495 is : Total No of layers: 61
#
# The content of the paragraph 496 is : No of layers with data: 34 Total Topology errors: 593 Gaps: 557
#
# The content of the paragraph 497 is : Overlap: 36
#
# The content of the paragraph 498 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 499 is : Ward N
#
# The content of the paragraph 500 is : Total No of layers: 60
#
# The content of the paragraph 501 is : No of layers with data: 44 Total Topology errors: 305 Gaps: 241
#
# The content of the paragraph 502 is : Overlap: 64
#
# The content of the paragraph 503 is : Overlay status (As per Quick Bird image from MCGM): Good
#
# The content of the paragraph 504 is : Ward P
#
# The content of the paragraph 505 is : Total No of layers: 61
#
# The content of the paragraph 506 is : No of layers with data: 42 Total Topology errors: 628 Gaps: 512
#
# The content of the paragraph 507 is : Overlap: 116
#
# The content of the paragraph 508 is : Overlay status (As per Quick Bird image from MCGM): Shift of 48 meters
#
# The content of the paragraph 509 is :
#
# The content of the paragraph 510 is : Ward R
#
# The content of the paragraph 511 is : Total No of layers: 61
#
# The content of the paragraph 512 is : No of layers with data: 40 Total Topology errors: 678 Gaps: 487
#
# The content of the paragraph 513 is : Overlap: 191
#
# The content of the paragraph 514 is : Overlay status (As per Quick Bird image from MCGM): Shift of 60 meters
#
# The content of the paragraph 515 is : Ward S
#
# The content of the paragraph 516 is : Total No of layers: 60
#
# The content of the paragraph 517 is : No of layers with data: 34 Total Topology errors: 274 Gaps: 165
#
# The content of the paragraph 518 is : Overlap: 109
#
# The content of the paragraph 519 is : Overlay status (As per Quick Bird image from MCGM): Shift of 60 meters
#
# The content of the paragraph 520 is : Ward T
#
# The content of the paragraph 521 is : Total No of layers: 61
#
# The content of the paragraph 522 is : No of layers with data: 32 Total Topology errors: 449 Gaps: 226
#
# The content of the paragraph 523 is : Overlap: 223
#
# The content of the paragraph 524 is : Overlay status (As per Quick Bird image from MCGM): Shift of 14 meters
#
# The content of the paragraph 525 is :
#
# The content of the paragraph 526 is : Way Forward
#
# The content of the paragraph 527 is :
#
# The content of the paragraph 528 is : The Consultant is currently working towards the creation of a database of acceptable accuracy. Rectification of errors on the GIS data provided is being done through the methods suggested above. Ward wise data layers are also being consolidated into a contiguous database for the entire area under MCGM jurisdiction.
#
# The content of the paragraph 529 is : Once the data is rectified, the Base Map will be prepared through consolidation of requisite layers as described above. This will serve as the base for the Existing Land Use mapping exercise.
#
# The content of the paragraph 530 is : Carrying out primary surveys to ascertain the existing land use will be the next step. These will result in overlays on the Base Map to create the Existing land Use Map.
#
# The content of the paragraph 531 is : Further overlays will be prepared for the sectoral findings from secondary surveys and data collected, towards existing situation analysis.
#
# The content of the paragraph 532 is :
#
# The content of the paragraph 533 is :
#
# The content of the paragraph 534 is :
#
# The content of the paragraph 535 is :

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in d:\users\saisagar\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in d:\users\saisagar\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import urllib.request as urllib2
from bs4 import BeautifulSoup

# %%
response=urllib2.urlopen("https://en.wikipedia.org/wiki/Natural_language_processing")
html_doc=response.read()

# %%
soup=BeautifulSoup(html_doc,'html.parser')
strhtm=soup.prettify()
print(strhtm[:5000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Natural language processing - Wikipedia
#   </title>
#   <script>
#    (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",
# "wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bb8cccbb-931f-4281-aaf8-3aff8c9effb8","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Natural_language_processing","wgTitle":"Natural language processing","wgCurRevisionId":1274942014,"wgRevisionId":1274942014,"wgArticleId":21652,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All accuracy disputes","Accuracy disputes from December 2013","Harv and Sfn no-target errors","CS1 errors: periodical ignored","CS1 maint: location","Articles with short description","Short description is different from Wikidata","Articles needing additional references from May 2024","All articles needing additional references","All articles with unsourced statements","Articles with unsourced statements from May 2024","Commons category link from Wikidata",
# "Natural language processing","Computational fields of study","Computational linguistics","Speech recognition"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Natural_language_processing","wgRelevantArticleId":21652,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":60000,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,
# "wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q30642","wgCheckUserClientHintsHeadersJsApi":["brands","architecture","bitness","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.scribunto.logs","site",
# "mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.bootstrap","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visu
